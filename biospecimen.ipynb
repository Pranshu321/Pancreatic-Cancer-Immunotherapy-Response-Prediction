# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
aliquot = pd.read_csv("datasets/biospecimen/aliquot.tsv", sep="\t")
df = pd.read_csv("datasets/biospecimen/slide.tsv", sep="\t")

# %%
df.head()
# Out:
#   project.project_id                         cases.case_id cases.submitter_id  \
# 0          TCGA-PAAD  712c2f78-c736-42ce-b689-a954c5290987       TCGA-IB-A7LX
# 1          TCGA-PAAD  712c2f78-c736-42ce-b689-a954c5290987       TCGA-IB-A7LX
# 2          TCGA-PAAD  2aaf212f-000a-4a9d-8a4a-198fa94f491e       TCGA-2J-AABI
# 3          TCGA-PAAD  2aaf212f-000a-4a9d-8a4a-198fa94f491e       TCGA-2J-AABI
# 4          TCGA-PAAD  4f87e061-e773-48f2-84ba-32401396500e       TCGA-IB-A5SQ
#
#                       samples.sample_id samples.submitter_id  \
# 0  33f3b071-4e98-4f77-938a-0054fa038e55     TCGA-IB-A7LX-01Z
# 1  d27fd323-24c9-4654-a8d5-42da2c54f294     TCGA-IB-A7LX-01A
# 2  5a7a09f6-7901-406d-b393-0885b3e81e92     TCGA-2J-AABI-01A
# 3  d0730b4f-3fbf-4058-aff3-e092140d039b     TCGA-2J-AABI-01Z
# 4  70ebc8c8-bfb1-4a94-a8f5-6d8ac9262bd1     TCGA-IB-A5SQ-01A
#
#                     portions.portion_id portions.submitter_id  \
# 0  c3f392f7-b627-51b0-8ecb-9e8e49373d18                   '--
# ...
